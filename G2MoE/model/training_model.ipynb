# %%
import os
import json
import copy
import time
import torch
import pickle
import random
import string
import logging
import numpy as np
import torch.nn as nn
from tqdm import tqdm
from G2MoE.utils import *
from G2MoE.model.Loss import Triplet
from G2MoE.model.Testing_Process import test_e2e
from G2MoE.model.Training_Process import train_e2e_moe, val_e2e_moe
from G2MoE.model.Graph_Constructor import Graph
from G2MoE.model.Graph_Encoder import Contrast_Encoder, End2End_Encoder
from G2MoE.model.MoEGAT import StepWiseGraphConvLayerMoE
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
args = {'gpu': 2, 'seed': 42, 'batch_size': 1, 'input': 768, 'hidden': 2048, 'heads': 128,
       'epochs': 100, 'log_every': 20, 'lr': 0.0003, 'dropout': 0.3, 'num_layers': 3, 'max_word_num': 185, 'kappa': 0.2, 'target_main_contribution': 0.6}

triple_args = {'margin': 0.5, 'topk': 5, 'thred': [0.4, 0.5]}

# if use_dynamic_topk is True --> top_k is the maximum of available topk
moe_args = {'num_experts': 3,
            'top_k': 3,
            'use_dynamic_topk': True}

# Config
EARLY_STOPPING_PATIENCE = 20 
EARLY_STOPPING_METRIC = "val_rouge2" 

dataset_name = "Abmusu_weight_blend_concateV2_contribute"  

model_save_root_path = '/kaggle/working/'
c_patient, s_patient = 30,30
best_r2, best_c_loss, best_s_loss = 0, 10000, 10000
history = {'loss': [], 'val_loss': []}
model_save_path = ""

seed_everything(args['seed'])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import pickle

# Load train
with open("/kaggle/input/vlsp-graphs-sent/trainGraphs.pkl", "rb") as f:
    trainGraphs = pickle.load(f)

# Load test
with open("/kaggle/input/vlsp-test-graph/testGraphs.pkl", "rb") as f:
    testGraphs = pickle.load(f)

print(f"Train graphs: {len(trainGraphs)} samples")
print(f"Test graphs: {len(testGraphs)} samples")
# Out:
# Train graphs: 200 samples
# Test graphs: 150 samples

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.21.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (6.33.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.33.2)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
import wandb
wandb.login(key="...")  # Add your wandb API key here
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: lexuanhung1234576 (TripleAIML) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# Initialize wandb
import wandb

use_dynamic_topk = moe_args['use_dynamic_topk']
target_main_contribution = args['target_main_contribution']

run_name = f"{dataset_name}_DynTopK-{use_dynamic_topk}_TMC-{target_main_contribution}"

wandb.init(
    project="MoEGAT",
    name=run_name,
    config={
        "learning_rate": args['lr'],
        "epochs": args['epochs'],
        "hidden_dim": args['hidden'],
        "dropout": args['dropout'],
        "heads": args['heads'],
        "max_word_num": args['max_word_num'],
        "kappa": args['kappa'],
        "num_experts": moe_args['num_experts'],
        "top_k": moe_args['top_k'],
        "use_dynamic_topk": use_dynamic_topk,
        "triplet_margin": triple_args['margin'],
        "triplet_topk": triple_args['topk'],
        "triple_thres0": triple_args['thred'][0],
        "triple_thres1": triple_args['thred'][1],
        "target_main_contribution": target_main_contribution,
    }
)

# Model initialization
c_graph_encoder = StepWiseGraphConvLayerMoE(
    in_dim=args['input'], out_dim=args['hidden'], hid_dim=args['hidden'],
    dropout_p=args['dropout'], act=nn.LeakyReLU(), nheads=args['heads'], iter=1, 
    num_experts=moe_args['num_experts'], top_k=moe_args['top_k'], 
    use_dynamic_topk=moe_args['use_dynamic_topk'], target_main_contribution=args['target_main_contribution']
).to(device)

contrast_filter = Contrast_Encoder(c_graph_encoder, args['hidden'], dropout_p=args['dropout']).to(device)
summarization_encoder = End2End_Encoder(args['input'], args['hidden'], args['dropout']).to(device)
loss_method = Triplet(margin=triple_args['margin'], topk=triple_args['topk'])

trainset = trainGraphs

optimizer = torch.optim.Adam([
    {'params': summarization_encoder.parameters()},
    {'params': contrast_filter.parameters()}
], lr=args['lr'], weight_decay=1e-5)
# Out:
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20251122_172003-1agf5aeo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Abmusu_weight_blend_concateV2_contribute_DynTopK-True_TMC-0.6
# wandb: ⭐️ View project at https://wandb.ai/TripleAIML/MoEGAT
# wandb: 🚀 View run at https://wandb.ai/TripleAIML/MoEGAT/runs/1agf5aeo

# %%
best_loss = float('inf')
early_stopping_counter = 0

wandb.watch(contrast_filter, log="all", log_freq=100)
wandb.watch(summarization_encoder, log="all", log_freq=100)

for i in range(args['epochs']):
    random.shuffle(trainset)

    if c_patient < 0:
        for p in contrast_filter.parameters():
            p.requires_grad = False

    model = [contrast_filter, summarization_encoder]

    train_loss, train_rouge2, train_c_loss, train_s_loss, train_moe_loss = train_e2e_moe(
        trainset, model, optimizer, loss_method,
        args['max_word_num'], args['kappa'], triple_args['thred'], epoch=i
    )

    history['loss'].append(train_loss)

    wandb.log({
        "epoch": i,
        "train/loss": train_loss,
        "train/c_loss": train_c_loss,
        "train/s_loss": train_s_loss,
        "train/moe_loss": train_moe_loss,
        "train/rouge2": train_rouge2
    })

    torch.cuda.empty_cache()

    if train_loss < best_loss:
        best_loss = train_loss
        early_stopping_counter = 0

        encoder_path = os.path.join(model_save_root_path, f"best_encoder_epoch{i}_loss{best_loss:.4f}.mdl")
        contrast_path = os.path.join(model_save_root_path, f"best_contrast_epoch{i}_loss{best_loss:.4f}.mdl")

        torch.save(summarization_encoder.state_dict(), encoder_path)
        torch.save(contrast_filter.state_dict(), contrast_path)

        wandb.log({
            "best_loss": best_loss,
            "best_epoch": i
        })

    else:
        early_stopping_counter += 1

    if early_stopping_counter >= EARLY_STOPPING_PATIENCE:
        break

wandb.finish()
# Out:
# Epoch 0
# Batch 0, Loss: 1.1995265483856201
# Batch 0, C-Loss: 1.575150489807129
# Batch 0, S-Loss: 2.0224266052246094
# Batch 0, MoE-Loss: 0.0010024189250543714
# Main contribution: 49.98%
# Dynamic Top-K: {'mean': 2.5142858028411865, 'std': 0.5034045577049255, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 1.073665976524353
# Batch 20, C-Loss: 1.7633060216903687
# Batch 20, S-Loss: 1.4570229053497314
# Batch 20, MoE-Loss: 0.0006688821595162153
# Main contribution: 58.05%
# Dynamic Top-K: {'mean': 2.5303030014038086, 'std': 0.5029052495956421, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 1.070842981338501
# Batch 40, C-Loss: 1.6801612377166748
# Batch 40, S-Loss: 1.5319209098815918
# Batch 40, MoE-Loss: 0.0004467074468266219
# Main contribution: 58.26%
# Dynamic Top-K: {'mean': 2.6500000953674316, 'std': 0.48304590582847595, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 1.0348056554794312
# Batch 60, C-Loss: 1.5173969268798828
# Batch 60, S-Loss: 1.5866889953613281
# Batch 60, MoE-Loss: 0.00033027486642822623
# Main contribution: 59.60%
# Dynamic Top-K: {'mean': 2.4533333778381348, 'std': 0.5011698007583618, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.9647864699363708
# Batch 80, C-Loss: 1.3333793878555298
# Batch 80, S-Loss: 1.5607054233551025
# Batch 80, MoE-Loss: 0.00027403736021369696
# Main contribution: 59.93%
# Dynamic Top-K: {'mean': 2.6000001430511475, 'std': 0.49613896012306213, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.9199435114860535
# Batch 100, C-Loss: 1.1907944679260254
# Batch 100, S-Loss: 1.568809151649475
# Batch 100, MoE-Loss: 0.00022669081226922572
# Main contribution: 59.89%
# Dynamic Top-K: {'mean': 2.3960394859313965, 'std': 0.4902879297733307, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.883137583732605
# Batch 120, C-Loss: 1.087395429611206
# Batch 120, S-Loss: 1.5618239641189575
# Batch 120, MoE-Loss: 0.00019308288756292313
# Main contribution: 59.53%
# Dynamic Top-K: {'mean': 2.2727272510528564, 'std': 0.44705840945243835, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.8512995839118958
# Batch 140, C-Loss: 1.0091506242752075
# Batch 140, S-Loss: 1.5445780754089355
# Batch 140, MoE-Loss: 0.00016963724920060486
# Main contribution: 60.34%
# Dynamic Top-K: {'mean': 2.395061731338501, 'std': 0.4919098913669586, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.8327426314353943
# Batch 160, C-Loss: 0.9495042562484741
# Batch 160, S-Loss: 1.5485700368881226
# Batch 160, MoE-Loss: 0.0001532601163489744
# Main contribution: 60.46%
# Dynamic Top-K: {'mean': 2.5208334922790527, 'std': 0.5048523545265198, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.8105471730232239
# Batch 180, C-Loss: 0.9022889733314514
# Batch 180, S-Loss: 1.5292075872421265
# Batch 180, MoE-Loss: 0.00014408909191843122
# Main contribution: 60.32%
# Dynamic Top-K: {'mean': 2.5, 'std': 0.5023753046989441, 'min': 2.0, 'max': 3.0}
# At Epoch 0, Train Loss: 0.7978593111038208, Train C-Loss: 0.865397036075592, Train S-Loss: 1.5280479192733765, Train MoE-Loss: 0.0001322073512710631, R2 score: 0.25225000000000003
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# At Epoch 0, Val Loss: 0.6614705920219421, Val CLoss: 0.5021767020225525, Val SLoss: 1.4822044372558594, Val MoELoss: 3.1000970921013504e-05, Val R2: 0.30034733333333336
# Val Main contribution: 59.69%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Epoch 0 Has best R2 Score of 0.30034733333333336, saved Model to /kaggle/working/c_0_0.30034733333333336.mdl
# Epoch 1
# Batch 0, Loss: 0.6203859448432922
# Batch 0, C-Loss: 0.5209908485412598
# Batch 0, S-Loss: 1.3401020765304565
# Batch 0, MoE-Loss: 6.485879566753283e-05
# Main contribution: 59.35%
# Dynamic Top-K: {'mean': 2.481818199157715, 'std': 0.5019561648368835, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6890371441841125
# Batch 20, C-Loss: 0.5110191106796265
# Batch 20, S-Loss: 1.5560725927352905
# Batch 20, MoE-Loss: 1.9500910639180802e-05
# Main contribution: 59.89%
# Dynamic Top-K: {'mean': 2.4250001907348633, 'std': 0.49641573429107666, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.668624222278595
# Batch 40, C-Loss: 0.5180184245109558
# Batch 40, S-Loss: 1.4878296852111816
# Batch 40, MoE-Loss: 2.4479511921526864e-05
# Main contribution: 59.94%
# Dynamic Top-K: {'mean': 2.3980581760406494, 'std': 0.4918912351131439, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6741805672645569
# Batch 60, C-Loss: 0.5241885185241699
# Batch 60, S-Loss: 1.4983265399932861
# Batch 60, MoE-Loss: 2.6670868464861996e-05
# Main contribution: 59.29%
# Dynamic Top-K: {'mean': 2.8399999141693115, 'std': 0.37416574358940125, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6681735515594482
# Batch 80, C-Loss: 0.5318699479103088
# Batch 80, S-Loss: 1.4726243019104004
# Batch 80, MoE-Loss: 2.6296502255718224e-05
# Main contribution: 59.53%
# Dynamic Top-K: {'mean': 2.2727272510528564, 'std': 0.44705840945243835, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6771652698516846
# Batch 100, C-Loss: 0.5305832028388977
# Batch 100, S-Loss: 1.5008866786956787
# Batch 100, MoE-Loss: 2.586889786471147e-05
# Main contribution: 59.64%
# Dynamic Top-K: {'mean': 2.615384578704834, 'std': 0.49286404252052307, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6655100584030151
# Batch 120, C-Loss: 0.5315736532211304
# Batch 120, S-Loss: 1.4649304151535034
# Batch 120, MoE-Loss: 2.5479925170657225e-05
# Main contribution: 60.07%
# Dynamic Top-K: {'mean': 2.4509804248809814, 'std': 0.5025425553321838, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6647669672966003
# Batch 140, C-Loss: 0.5321085453033447
# Batch 140, S-Loss: 1.4621639251708984
# Batch 140, MoE-Loss: 2.8089589250157587e-05
# Main contribution: 59.96%
# Dynamic Top-K: {'mean': 2.3106796741485596, 'std': 0.4650348126888275, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6667490005493164
# Batch 160, C-Loss: 0.5316715240478516
# Batch 160, S-Loss: 1.4685472249984741
# Batch 160, MoE-Loss: 2.8040567485732026e-05
# Main contribution: 60.51%
# Dynamic Top-K: {'mean': 2.345794200897217, 'std': 0.4778648614883423, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6651256084442139
# Batch 180, C-Loss: 0.532251238822937
# Batch 180, S-Loss: 1.4630948305130005
# Batch 180, MoE-Loss: 3.068836304009892e-05
# Main contribution: 59.53%
# Dynamic Top-K: {'mean': 2.528090000152588, 'std': 0.5020387768745422, 'min': 2.0, 'max': 3.0}
# At Epoch 1, Train Loss: 0.6738898158073425, Train C-Loss: 0.5306307673454285, Train S-Loss: 1.4910061359405518, Train MoE-Loss: 3.24798165820539e-05, R2 score: 0.29278
# At Epoch 1, Val Loss: 0.6540411114692688, Val CLoss: 0.505739688873291, Val SLoss: 1.4563697576522827, Val MoELoss: 1.4883474250382278e-05, Val R2: 0.3118606666666667
# Val Main contribution: 60.02%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Epoch 1 Has best R2 Score of 0.3118606666666667, saved Model to /kaggle/working/c_1_0.3118606666666667.mdl
# Epoch 2
# Batch 0, Loss: 0.6232273578643799
# Batch 0, C-Loss: 0.5241489410400391
# Batch 0, S-Loss: 1.3455063104629517
# Batch 0, MoE-Loss: 2.6876330593950115e-05
# Main contribution: 60.27%
# Dynamic Top-K: {'mean': 2.3523809909820557, 'std': 0.48000308871269226, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6610826253890991
# Batch 20, C-Loss: 0.5379325151443481
# Batch 20, S-Loss: 1.4452829360961914
# Batch 20, MoE-Loss: 3.224054671591148e-05
# Main contribution: 60.33%
# Dynamic Top-K: {'mean': 2.637681245803833, 'std': 0.4841917157173157, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6506929397583008
# Batch 40, C-Loss: 0.5294162631034851
# Batch 40, S-Loss: 1.4226266145706177
# Batch 40, MoE-Loss: 3.602244032663293e-05
# Main contribution: 60.99%
# Dynamic Top-K: {'mean': 2.329411745071411, 'std': 0.4727889597415924, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.661328911781311
# Batch 60, C-Loss: 0.5286740660667419
# Batch 60, S-Loss: 1.4552741050720215
# Batch 60, MoE-Loss: 3.824899249593727e-05
# Main contribution: 60.72%
# Dynamic Top-K: {'mean': 2.9487180709838867, 'std': 0.22345586121082306, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6612633466720581
# Batch 80, C-Loss: 0.5287443399429321
# Batch 80, S-Loss: 1.4550111293792725
# Batch 80, MoE-Loss: 3.452049713814631e-05
# Main contribution: 60.05%
# Dynamic Top-K: {'mean': 2.838709592819214, 'std': 0.37387827038764954, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6618093848228455
# Batch 100, C-Loss: 0.5279635190963745
# Batch 100, S-Loss: 1.4574288129806519
# Batch 100, MoE-Loss: 3.605623351177201e-05
# Main contribution: 59.57%
# Dynamic Top-K: {'mean': 2.7317070960998535, 'std': 0.4485749900341034, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6696664690971375
# Batch 120, C-Loss: 0.5284971594810486
# Batch 120, S-Loss: 1.480462908744812
# Batch 120, MoE-Loss: 3.969847966800444e-05
# Main contribution: 59.99%
# Dynamic Top-K: {'mean': 2.438596487045288, 'std': 0.5006261467933655, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6697899103164673
# Batch 140, C-Loss: 0.527505099773407
# Batch 140, S-Loss: 1.4818278551101685
# Batch 140, MoE-Loss: 3.7125581002328545e-05
# Main contribution: 60.04%
# Dynamic Top-K: {'mean': 2.4509804248809814, 'std': 0.5025425553321838, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6660820841789246
# Batch 160, C-Loss: 0.5272722244262695
# Batch 160, S-Loss: 1.4709376096725464
# Batch 160, MoE-Loss: 3.7354595406213775e-05
# Main contribution: 59.76%
# Dynamic Top-K: {'mean': 2.444444417953491, 'std': 0.4992206394672394, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6652897000312805
# Batch 180, C-Loss: 0.526651918888092
# Batch 180, S-Loss: 1.4691808223724365
# Batch 180, MoE-Loss: 3.669512443593703e-05
# Main contribution: 59.89%
# Dynamic Top-K: {'mean': 2.367347002029419, 'std': 0.4845607280731201, 'min': 2.0, 'max': 3.0}
# At Epoch 2, Train Loss: 0.6597865223884583, Train C-Loss: 0.528818666934967, Train S-Loss: 1.4505051374435425, Train MoE-Loss: 3.607599501265213e-05, R2 score: 0.3039095
# At Epoch 2, Val Loss: 0.640749990940094, Val CLoss: 0.5102219581604004, Val SLoss: 1.4120171070098877, Val MoELoss: 1.0992735951731447e-05, Val R2: 0.31077333333333335
# Val Main contribution: 60.03%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 1/20
# Epoch 3
# Batch 0, Loss: 0.8454917669296265
# Batch 0, C-Loss: 0.5183682441711426
# Batch 0, S-Loss: 2.0180699825286865
# Batch 0, MoE-Loss: 3.6986468330724165e-05
# Main contribution: 59.63%
# Dynamic Top-K: {'mean': 2.615384578704834, 'std': 0.49286404252052307, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6634958386421204
# Batch 20, C-Loss: 0.5177995562553406
# Batch 20, S-Loss: 1.4726505279541016
# Batch 20, MoE-Loss: 3.723507688846439e-05
# Main contribution: 60.39%
# Dynamic Top-K: {'mean': 2.5208334922790527, 'std': 0.5048523545265198, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6541638970375061
# Batch 40, C-Loss: 0.5256807804107666
# Batch 40, S-Loss: 1.4367756843566895
# Batch 40, MoE-Loss: 3.4881380997831e-05
# Main contribution: 59.77%
# Dynamic Top-K: {'mean': 2.685185194015503, 'std': 0.46880316734313965, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.654496431350708
# Batch 60, C-Loss: 0.5217556953430176
# Batch 60, S-Loss: 1.4417026042938232
# Batch 60, MoE-Loss: 3.0751376471016556e-05
# Main contribution: 60.12%
# Dynamic Top-K: {'mean': 2.561403512954712, 'std': 0.5006261467933655, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6450265645980835
# Batch 80, C-Loss: 0.5190256237983704
# Batch 80, S-Loss: 1.416023850440979
# Batch 80, MoE-Loss: 2.9920516681158915e-05
# Main contribution: 60.38%
# Dynamic Top-K: {'mean': 2.762711763381958, 'std': 0.4290720820426941, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6401375532150269
# Batch 100, C-Loss: 0.5171993374824524
# Batch 100, S-Loss: 1.4031838178634644
# Batch 100, MoE-Loss: 2.912449235736858e-05
# Main contribution: 59.77%
# Dynamic Top-K: {'mean': 2.345794200897217, 'std': 0.4778648614883423, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6423760056495667
# Batch 120, C-Loss: 0.5163255333900452
# Batch 120, S-Loss: 1.4107744693756104
# Batch 120, MoE-Loss: 2.779510396067053e-05
# Main contribution: 60.28%
# Dynamic Top-K: {'mean': 2.4782609939575195, 'std': 0.503186821937561, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6441971659660339
# Batch 140, C-Loss: 0.5155113339424133
# Batch 140, S-Loss: 1.417051076889038
# Batch 140, MoE-Loss: 2.9045708288322203e-05
# Main contribution: 59.19%
# Dynamic Top-K: {'mean': 2.2903225421905518, 'std': 0.45513638854026794, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6481287479400635
# Batch 160, C-Loss: 0.515583872795105
# Batch 160, S-Loss: 1.4287729263305664
# Batch 160, MoE-Loss: 2.9678067221539095e-05
# Main contribution: 59.74%
# Dynamic Top-K: {'mean': 2.3684210777282715, 'std': 0.4849355220794678, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.654883861541748
# Batch 180, C-Loss: 0.5152096748352051
# Batch 180, S-Loss: 1.4494118690490723
# Batch 180, MoE-Loss: 2.992976806126535e-05
# Main contribution: 60.29%
# Dynamic Top-K: {'mean': 2.581395387649536, 'std': 0.49916872382164, 'min': 2.0, 'max': 3.0}
# At Epoch 3, Train Loss: 0.6530020236968994, Train C-Loss: 0.5157352685928345, Train S-Loss: 1.4432412385940552, Train MoE-Loss: 2.9054728656774387e-05, R2 score: 0.3106905
# At Epoch 3, Val Loss: 0.6291000247001648, Val CLoss: 0.509785532951355, Val SLoss: 1.3774917125701904, Val MoELoss: 2.2837795768282376e-05, Val R2: 0.312058
# Val Main contribution: 59.77%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Epoch 3 Has best R2 Score of 0.312058, saved Model to /kaggle/working/c_3_0.312058.mdl
# Epoch 4
# Batch 0, Loss: 0.7262188792228699
# Batch 0, C-Loss: 0.5120201110839844
# Batch 0, S-Loss: 1.6666309833526611
# Batch 0, MoE-Loss: 5.420446086645825e-06
# Main contribution: 60.05%
# Dynamic Top-K: {'mean': 2.7291667461395264, 'std': 0.4490928649902344, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6795322895050049
# Batch 20, C-Loss: 0.5138427019119263
# Batch 20, S-Loss: 1.5247312784194946
# Batch 20, MoE-Loss: 2.2852789697935805e-05
# Main contribution: 60.25%
# Dynamic Top-K: {'mean': 2.438596487045288, 'std': 0.5006261467933655, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6602163314819336
# Batch 40, C-Loss: 0.5137999057769775
# Batch 40, S-Loss: 1.466815710067749
# Batch 40, MoE-Loss: 3.345337972859852e-05
# Main contribution: 59.41%
# Dynamic Top-K: {'mean': 2.316239356994629, 'std': 0.4660043716430664, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6559540629386902
# Batch 60, C-Loss: 0.512094259262085
# Batch 60, S-Loss: 1.4557366371154785
# Batch 60, MoE-Loss: 3.108278542640619e-05
# Main contribution: 60.33%
# Dynamic Top-K: {'mean': 2.7272727489471436, 'std': 0.45226702094078064, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6437148451805115
# Batch 80, C-Loss: 0.5123003125190735
# Batch 80, S-Loss: 1.418809175491333
# Batch 80, MoE-Loss: 3.467448550509289e-05
# Main contribution: 58.70%
# Dynamic Top-K: {'mean': 2.2957746982574463, 'std': 0.45746535062789917, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6542700529098511
# Batch 100, C-Loss: 0.512220561504364
# Batch 100, S-Loss: 1.4505560398101807
# Batch 100, MoE-Loss: 3.321037002024241e-05
# Main contribution: 59.93%
# Dynamic Top-K: {'mean': 2.646341323852539, 'std': 0.48104700446128845, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.65362548828125
# Batch 120, C-Loss: 0.5110712647438049
# Batch 120, S-Loss: 1.4497736692428589
# Batch 120, MoE-Loss: 3.112308695563115e-05
# Main contribution: 60.14%
# Dynamic Top-K: {'mean': 2.453608274459839, 'std': 0.5004294514656067, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6520683765411377
# Batch 140, C-Loss: 0.510687530040741
# Batch 140, S-Loss: 1.445488452911377
# Batch 140, MoE-Loss: 2.9724886189796962e-05
# Main contribution: 60.08%
# Dynamic Top-K: {'mean': 2.438202381134033, 'std': 0.49897754192352295, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6508944630622864
# Batch 160, C-Loss: 0.5103371143341064
# Batch 160, S-Loss: 1.4423173666000366
# Batch 160, MoE-Loss: 2.9551138140959665e-05
# Main contribution: 60.25%
# Dynamic Top-K: {'mean': 2.622950553894043, 'std': 0.4886694550514221, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6518025398254395
# Batch 180, C-Loss: 0.510662853717804
# Batch 180, S-Loss: 1.4447150230407715
# Batch 180, MoE-Loss: 3.031333108083345e-05
# Main contribution: 59.84%
# Dynamic Top-K: {'mean': 2.3046875, 'std': 0.46208351850509644, 'min': 2.0, 'max': 3.0}
# At Epoch 4, Train Loss: 0.6502809524536133, Train C-Loss: 0.5107842087745667, Train S-Loss: 1.4400302171707153, Train MoE-Loss: 2.896786099881865e-05, R2 score: 0.307742
# At Epoch 4, Val Loss: 0.6313531994819641, Val CLoss: 0.5041208863258362, Val SLoss: 1.3899271488189697, Val MoELoss: 1.1251334399275947e-05, Val R2: 0.3091526666666667
# Val Main contribution: 59.89%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 1/20
# Epoch 5
# Batch 0, Loss: 0.8755590319633484
# Batch 0, C-Loss: 0.5026822090148926
# Batch 0, S-Loss: 2.123981475830078
# Batch 0, MoE-Loss: 1.3434290849545505e-05
# Main contribution: 59.87%
# Dynamic Top-K: {'mean': 2.9600000381469727, 'std': 0.20000000298023224, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6760963201522827
# Batch 20, C-Loss: 0.5064089894294739
# Batch 20, S-Loss: 1.5218603610992432
# Batch 20, MoE-Loss: 1.955977495526895e-05
# Main contribution: 59.73%
# Dynamic Top-K: {'mean': 2.5303030014038086, 'std': 0.5029052495956421, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6675334572792053
# Batch 40, C-Loss: 0.5059413313865662
# Batch 40, S-Loss: 1.4966355562210083
# Batch 40, MoE-Loss: 2.3308233721763827e-05
# Main contribution: 59.64%
# Dynamic Top-K: {'mean': 2.5194804668426514, 'std': 0.5028966069221497, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6580888628959656
# Batch 60, C-Loss: 0.5089370608329773
# Batch 60, S-Loss: 1.4653048515319824
# Batch 60, MoE-Loss: 2.4221946659963578e-05
# Main contribution: 60.44%
# Dynamic Top-K: {'mean': 2.414285659790039, 'std': 0.4961549937725067, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6601244211196899
# Batch 80, C-Loss: 0.5083931088447571
# Batch 80, S-Loss: 1.4719524383544922
# Batch 80, MoE-Loss: 2.7261288778390735e-05
# Main contribution: 60.11%
# Dynamic Top-K: {'mean': 2.385714292526245, 'std': 0.4902781546115875, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6617599129676819
# Batch 100, C-Loss: 0.5077199339866638
# Batch 100, S-Loss: 1.4775300025939941
# Batch 100, MoE-Loss: 2.955214040412102e-05
# Main contribution: 59.72%
# Dynamic Top-K: {'mean': 2.50649356842041, 'std': 0.5032362937927246, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.659792959690094
# Batch 120, C-Loss: 0.5086628198623657
# Batch 120, S-Loss: 1.4706860780715942
# Batch 120, MoE-Loss: 2.951966780528892e-05
# Main contribution: 60.15%
# Dynamic Top-K: {'mean': 2.7272727489471436, 'std': 0.45226702094078064, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6564849615097046
# Batch 140, C-Loss: 0.5089013576507568
# Batch 140, S-Loss: 1.46052086353302
# Batch 140, MoE-Loss: 3.218157507944852e-05
# Main contribution: 59.17%
# Dynamic Top-K: {'mean': 2.4193546772003174, 'std': 0.4954553544521332, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6547883152961731
# Batch 160, C-Loss: 0.508602499961853
# Batch 160, S-Loss: 1.4557287693023682
# Batch 160, MoE-Loss: 3.3218104363186285e-05
# Main contribution: 59.74%
# Dynamic Top-K: {'mean': 2.4864864349365234, 'std': 0.5032291412353516, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6507789492607117
# Batch 180, C-Loss: 0.5087710022926331
# Batch 180, S-Loss: 1.443532109260559
# Batch 180, MoE-Loss: 3.325173383927904e-05
# Main contribution: 60.14%
# Dynamic Top-K: {'mean': 2.418367385864258, 'std': 0.495827317237854, 'min': 2.0, 'max': 3.0}
# At Epoch 5, Train Loss: 0.6469861268997192, Train C-Loss: 0.509132981300354, Train S-Loss: 1.4317926168441772, Train MoE-Loss: 3.225595719413832e-05, R2 score: 0.3056665
# At Epoch 5, Val Loss: 0.6292412877082825, Val CLoss: 0.5058058500289917, Val SLoss: 1.3819035291671753, Val MoELoss: 1.4640141671407036e-05, Val R2: 0.31025733333333333
# Val Main contribution: 60.13%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 2/20
# Epoch 6
# Batch 0, Loss: 0.6057391166687012
# Batch 0, C-Loss: 0.511260986328125
# Batch 0, S-Loss: 1.3059481382369995
# Batch 0, MoE-Loss: 8.145570973283611e-06
# Main contribution: 59.92%
# Dynamic Top-K: {'mean': 2.4040403366088867, 'std': 0.49320265650749207, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6456096768379211
# Batch 20, C-Loss: 0.5064736008644104
# Batch 20, S-Loss: 1.4303230047225952
# Batch 20, MoE-Loss: 3.2438292691949755e-05
# Main contribution: 60.05%
# Dynamic Top-K: {'mean': 2.433734893798828, 'std': 0.4986022710800171, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6216246485710144
# Batch 40, C-Loss: 0.5083638429641724
# Batch 40, S-Loss: 1.3564695119857788
# Batch 40, MoE-Loss: 4.0610604628454894e-05
# Main contribution: 59.53%
# Dynamic Top-K: {'mean': 2.8620688915252686, 'std': 0.35093119740486145, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6303793787956238
# Batch 60, C-Loss: 0.5076408386230469
# Batch 60, S-Loss: 1.3834378719329834
# Batch 60, MoE-Loss: 5.9635691286530346e-05
# Main contribution: 57.29%
# Dynamic Top-K: {'mean': 2.3523809909820557, 'std': 0.48000308871269226, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6115671396255493
# Batch 80, C-Loss: 0.5097211003303528
# Batch 80, S-Loss: 1.324892520904541
# Batch 80, MoE-Loss: 8.786213584244251e-05
# Main contribution: 56.83%
# Dynamic Top-K: {'mean': 2.4533333778381348, 'std': 0.5011698007583618, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6297991871833801
# Batch 100, C-Loss: 0.5116583704948425
# Batch 100, S-Loss: 1.3775990009307861
# Batch 100, MoE-Loss: 0.00014002375246491283
# Main contribution: 60.35%
# Dynamic Top-K: {'mean': 2.5180721282958984, 'std': 0.5027108788490295, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6391892433166504
# Batch 120, C-Loss: 0.51192307472229
# Batch 120, S-Loss: 1.405517339706421
# Batch 120, MoE-Loss: 0.0001274154201382771
# Main contribution: 59.49%
# Dynamic Top-K: {'mean': 2.5, 'std': 0.5037175416946411, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6425163149833679
# Batch 140, C-Loss: 0.5123679041862488
# Batch 140, S-Loss: 1.41506028175354
# Batch 140, MoE-Loss: 0.00012113803677493706
# Main contribution: 59.05%
# Dynamic Top-K: {'mean': 2.465517282485962, 'std': 0.5031660199165344, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6486237049102783
# Batch 160, C-Loss: 0.5114570260047913
# Batch 160, S-Loss: 1.4343013763427734
# Batch 160, MoE-Loss: 0.00011299589823465794
# Main contribution: 59.91%
# Dynamic Top-K: {'mean': 2.317073106765747, 'std': 0.4672394394874573, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6503018736839294
# Batch 180, C-Loss: 0.5107215046882629
# Batch 180, S-Loss: 1.440077543258667
# Batch 180, MoE-Loss: 0.00010637257946655154
# Main contribution: 59.62%
# Dynamic Top-K: {'mean': 2.3960394859313965, 'std': 0.4902879297733307, 'min': 2.0, 'max': 3.0}
# At Epoch 6, Train Loss: 0.6484748721122742, Train C-Loss: 0.5104348063468933, Train S-Loss: 1.4348907470703125, Train MoE-Loss: 9.889033390209079e-05, R2 score: 0.30583200000000005
# At Epoch 6, Val Loss: 0.6284908056259155, Val CLoss: 0.508575439453125, Val SLoss: 1.3768564462661743, Val MoELoss: 3.961465699831024e-05, Val R2: 0.3113166666666667
# Val Main contribution: 60.39%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 3/20
# Epoch 7
# Batch 0, Loss: 0.7124311327934265
# Batch 0, C-Loss: 0.5072879791259766
# Batch 0, S-Loss: 1.6299713850021362
# Batch 0, MoE-Loss: 3.375053347554058e-05
# Main contribution: 60.34%
# Dynamic Top-K: {'mean': 2.5, 'std': 0.5043668746948242, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6258854269981384
# Batch 20, C-Loss: 0.50757896900177
# Batch 20, S-Loss: 1.3700485229492188
# Batch 20, MoE-Loss: 2.8575293981702998e-05
# Main contribution: 59.56%
# Dynamic Top-K: {'mean': 2.4787232875823975, 'std': 0.5022256970405579, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6217671036720276
# Batch 40, C-Loss: 0.509295642375946
# Batch 40, S-Loss: 1.3559757471084595
# Batch 40, MoE-Loss: 2.9586339223897085e-05
# Main contribution: 60.03%
# Dynamic Top-K: {'mean': 2.4274191856384277, 'std': 0.4967109262943268, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6266272664070129
# Batch 60, C-Loss: 0.5079519748687744
# Batch 60, S-Loss: 1.371896743774414
# Batch 60, MoE-Loss: 3.2707437640056014e-05
# Main contribution: 60.62%
# Dynamic Top-K: {'mean': 2.6666667461395264, 'std': 0.4803844690322876, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6394150853157043
# Batch 80, C-Loss: 0.5069446563720703
# Batch 80, S-Loss: 1.4112695455551147
# Batch 80, MoE-Loss: 3.1047864467836916e-05
# Main contribution: 59.78%
# Dynamic Top-K: {'mean': 2.5, 'std': 0.5037175416946411, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6444457769393921
# Batch 100, C-Loss: 0.5064390301704407
# Batch 100, S-Loss: 1.4268654584884644
# Batch 100, MoE-Loss: 3.2896572520257905e-05
# Main contribution: 59.66%
# Dynamic Top-K: {'mean': 3.000000238418579, 'std': 0.0, 'min': 3.0, 'max': 3.0}
# Batch 120, Loss: 0.6448092460632324
# Batch 120, C-Loss: 0.5062692165374756
# Batch 120, S-Loss: 1.4281249046325684
# Batch 120, MoE-Loss: 3.3802974940044805e-05
# Main contribution: 60.86%
# Dynamic Top-K: {'mean': 2.637681245803833, 'std': 0.4841917157173157, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6504667401313782
# Batch 140, C-Loss: 0.505963921546936
# Batch 140, S-Loss: 1.4454017877578735
# Batch 140, MoE-Loss: 3.4292053896933794e-05
# Main contribution: 60.16%
# Dynamic Top-K: {'mean': 2.588235378265381, 'std': 0.49705013632774353, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6438965797424316
# Batch 160, C-Loss: 0.5057352781295776
# Batch 160, S-Loss: 1.4259185791015625
# Batch 160, MoE-Loss: 3.549400935298763e-05
# Main contribution: 60.80%
# Dynamic Top-K: {'mean': 2.5957446098327637, 'std': 0.49605289101600647, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.649701714515686
# Batch 180, C-Loss: 0.5057348012924194
# Batch 180, S-Loss: 1.4433335065841675
# Batch 180, MoE-Loss: 3.6600104067474604e-05
# Main contribution: 59.28%
# Dynamic Top-K: {'mean': 2.4827585220336914, 'std': 0.5040669441223145, 'min': 2.0, 'max': 3.0}
# At Epoch 7, Train Loss: 0.6488415598869324, Train C-Loss: 0.5061590075492859, Train S-Loss: 1.4403283596038818, Train MoE-Loss: 3.654350803117268e-05, R2 score: 0.3107745
# At Epoch 7, Val Loss: 0.6317132711410522, Val CLoss: 0.504427969455719, Val SLoss: 1.390696406364441, Val MoELoss: 1.5467625416931696e-05, Val R2: 0.3130266666666667
# Val Main contribution: 59.86%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Epoch 7 Has best R2 Score of 0.3130266666666667, saved Model to /kaggle/working/c_7_0.3130266666666667.mdl
# Epoch 8
# Batch 0, Loss: 0.6479786038398743
# Batch 0, C-Loss: 0.511929988861084
# Batch 0, S-Loss: 1.431985855102539
# Batch 0, MoE-Loss: 1.985788367164787e-05
# Main contribution: 60.20%
# Dynamic Top-K: {'mean': 2.469026565551758, 'std': 0.5012626051902771, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6220664978027344
# Batch 20, C-Loss: 0.5046446323394775
# Batch 20, S-Loss: 1.3615161180496216
# Batch 20, MoE-Loss: 3.865588587359525e-05
# Main contribution: 59.42%
# Dynamic Top-K: {'mean': 2.555555820465088, 'std': 0.5008952617645264, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6279630064964294
# Batch 40, C-Loss: 0.5071794986724854
# Batch 40, S-Loss: 1.3766635656356812
# Batch 40, MoE-Loss: 4.6283264964586124e-05
# Main contribution: 59.59%
# Dynamic Top-K: {'mean': 2.6458334922790527, 'std': 0.48332110047340393, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6375328302383423
# Batch 60, C-Loss: 0.5073451995849609
# Batch 60, S-Loss: 1.4052098989486694
# Batch 60, MoE-Loss: 4.309569703764282e-05
# Main contribution: 60.17%
# Dynamic Top-K: {'mean': 2.5342464447021484, 'std': 0.5022779107093811, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6442364454269409
# Batch 80, C-Loss: 0.5070515275001526
# Batch 80, S-Loss: 1.4256166219711304
# Batch 80, MoE-Loss: 4.113356408197433e-05
# Main contribution: 60.33%
# Dynamic Top-K: {'mean': 2.366666793823242, 'std': 0.483508825302124, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6477829217910767
# Batch 100, C-Loss: 0.5081610679626465
# Batch 100, S-Loss: 1.4351493120193481
# Batch 100, MoE-Loss: 3.85138118872419e-05
# Main contribution: 59.37%
# Dynamic Top-K: {'mean': 2.279411792755127, 'std': 0.4503690004348755, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.644079864025116
# Batch 120, C-Loss: 0.5077521204948425
# Batch 120, S-Loss: 1.4244483709335327
# Batch 120, MoE-Loss: 3.9402671973221004e-05
# Main contribution: 59.76%
# Dynamic Top-K: {'mean': 2.481818199157715, 'std': 0.5019561648368835, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6463987827301025
# Batch 140, C-Loss: 0.5072667598724365
# Batch 140, S-Loss: 1.4318903684616089
# Batch 140, MoE-Loss: 3.921086681657471e-05
# Main contribution: 61.45%
# Dynamic Top-K: {'mean': 2.4782609939575195, 'std': 0.503186821937561, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6455615758895874
# Batch 160, C-Loss: 0.5070788264274597
# Batch 160, S-Loss: 1.4295680522918701
# Batch 160, MoE-Loss: 3.777301390073262e-05
# Main contribution: 59.63%
# Dynamic Top-K: {'mean': 2.50649356842041, 'std': 0.5032362937927246, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6469504833221436
# Batch 180, C-Loss: 0.506950855255127
# Batch 180, S-Loss: 1.4338608980178833
# Batch 180, MoE-Loss: 3.9839724195189774e-05
# Main contribution: 59.90%
# Dynamic Top-K: {'mean': 2.384615421295166, 'std': 0.48965319991111755, 'min': 2.0, 'max': 3.0}
# At Epoch 8, Train Loss: 0.6447799801826477, Train C-Loss: 0.5068749189376831, Train S-Loss: 1.427427053451538, Train MoE-Loss: 3.8018250052118674e-05, R2 score: 0.300645
# At Epoch 8, Val Loss: 0.6293852925300598, Val CLoss: 0.5029166340827942, Val SLoss: 1.3852200508117676, Val MoELoss: 1.9141440134262666e-05, Val R2: 0.31233133333333335
# Val Main contribution: 60.19%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 1/20
# Epoch 9
# Batch 0, Loss: 0.5579414367675781
# Batch 0, C-Loss: 0.505795955657959
# Batch 0, S-Loss: 1.1680281162261963
# Batch 0, MoE-Loss: 2.47955313170678e-07
# Main contribution: 60.00%
# Dynamic Top-K: {'mean': 2.4533333778381348, 'std': 0.5011698007583618, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6268276572227478
# Batch 20, C-Loss: 0.5040228962898254
# Batch 20, S-Loss: 1.3764293193817139
# Batch 20, MoE-Loss: 3.066613498958759e-05
# Main contribution: 59.99%
# Dynamic Top-K: {'mean': 2.6323530673980713, 'std': 0.4857495129108429, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6257349848747253
# Batch 40, C-Loss: 0.5040530562400818
# Batch 40, S-Loss: 1.3731125593185425
# Batch 40, MoE-Loss: 3.924340853700414e-05
# Main contribution: 60.50%
# Dynamic Top-K: {'mean': 2.4509804248809814, 'std': 0.5025425553321838, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6290749311447144
# Batch 60, C-Loss: 0.5058211088180542
# Batch 60, S-Loss: 1.3813644647598267
# Batch 60, MoE-Loss: 3.893014581990428e-05
# Main contribution: 60.44%
# Dynamic Top-K: {'mean': 2.5441176891326904, 'std': 0.5017528533935547, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6212257146835327
# Batch 80, C-Loss: 0.505916178226471
# Batch 80, S-Loss: 1.3577228784561157
# Batch 80, MoE-Loss: 3.7380788853624836e-05
# Main contribution: 60.06%
# Dynamic Top-K: {'mean': 2.375, 'std': 0.4866642951965332, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6356139779090881
# Batch 100, C-Loss: 0.5067025423049927
# Batch 100, S-Loss: 1.4000983238220215
# Batch 100, MoE-Loss: 4.0690698369871825e-05
# Main contribution: 58.96%
# Dynamic Top-K: {'mean': 2.5172414779663086, 'std': 0.5018705725669861, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6395028233528137
# Batch 120, C-Loss: 0.5074480175971985
# Batch 120, S-Loss: 1.4110163450241089
# Batch 120, MoE-Loss: 4.324255860410631e-05
# Main contribution: 59.50%
# Dynamic Top-K: {'mean': 2.5, 'std': 0.5028011798858643, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6351127028465271
# Batch 140, C-Loss: 0.5070639252662659
# Batch 140, S-Loss: 1.3982326984405518
# Batch 140, MoE-Loss: 4.075139804626815e-05
# Main contribution: 59.99%
# Dynamic Top-K: {'mean': 2.4117648601531982, 'std': 0.49705010652542114, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6440334320068359
# Batch 160, C-Loss: 0.5067416429519653
# Batch 160, S-Loss: 1.4253196716308594
# Batch 160, MoE-Loss: 3.871650551445782e-05
# Main contribution: 60.11%
# Dynamic Top-K: {'mean': 2.4383561611175537, 'std': 0.49961933493614197, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6444682478904724
# Batch 180, C-Loss: 0.5064966082572937
# Batch 180, S-Loss: 1.4268690347671509
# Batch 180, MoE-Loss: 3.878768256981857e-05
# Main contribution: 60.73%
# Dynamic Top-K: {'mean': 2.9000000953674316, 'std': 0.3038218021392822, 'min': 2.0, 'max': 3.0}
# At Epoch 9, Train Loss: 0.6498949527740479, Train C-Loss: 0.5062718391418457, Train S-Loss: 1.443374752998352, Train MoE-Loss: 3.755912621272728e-05, R2 score: 0.3081645
# At Epoch 9, Val Loss: 0.6563096046447754, Val CLoss: 0.5028650164604187, Val SLoss: 1.4660531282424927, Val MoELoss: 1.0973121788993012e-05, Val R2: 0.312822
# Val Main contribution: 59.93%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 2/20
# Epoch 10
# Batch 0, Loss: 0.5822670459747314
# Batch 0, C-Loss: 0.5021157264709473
# Batch 0, S-Loss: 1.2446746826171875
# Batch 0, MoE-Loss: 1.071274255082244e-05
# Main contribution: 60.11%
# Dynamic Top-K: {'mean': 2.50649356842041, 'std': 0.5032362937927246, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6140161156654358
# Batch 20, C-Loss: 0.5090829133987427
# Batch 20, S-Loss: 1.332931399345398
# Batch 20, MoE-Loss: 3.3845019061118364e-05
# Main contribution: 59.94%
# Dynamic Top-K: {'mean': 2.625, 'std': 0.49186936020851135, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6362086534500122
# Batch 40, C-Loss: 0.5080843567848206
# Batch 40, S-Loss: 1.4005073308944702
# Batch 40, MoE-Loss: 3.394210943952203e-05
# Main contribution: 59.60%
# Dynamic Top-K: {'mean': 2.289340019226074, 'std': 0.4546113908290863, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6466169357299805
# Batch 60, C-Loss: 0.5070117115974426
# Batch 60, S-Loss: 1.4328036308288574
# Batch 60, MoE-Loss: 3.490380913717672e-05
# Main contribution: 59.33%
# Dynamic Top-K: {'mean': 2.875, 'std': 0.34156501293182373, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6512356400489807
# Batch 80, C-Loss: 0.5063397288322449
# Batch 80, S-Loss: 1.4473341703414917
# Batch 80, MoE-Loss: 3.281733734183945e-05
# Main contribution: 59.41%
# Dynamic Top-K: {'mean': 2.316239356994629, 'std': 0.4660043716430664, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6499599814414978
# Batch 100, C-Loss: 0.5057865381240845
# Batch 100, S-Loss: 1.444061517715454
# Batch 100, MoE-Loss: 3.1483228667639196e-05
# Main contribution: 59.69%
# Dynamic Top-K: {'mean': 2.528090000152588, 'std': 0.5020387768745422, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6551686525344849
# Batch 120, C-Loss: 0.5059301853179932
# Batch 120, S-Loss: 1.4595441818237305
# Batch 120, MoE-Loss: 3.137094245175831e-05
# Main contribution: 59.29%
# Dynamic Top-K: {'mean': 2.5764706134796143, 'std': 0.4970501661300659, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6499327421188354
# Batch 140, C-Loss: 0.5064201354980469
# Batch 140, S-Loss: 1.4433470964431763
# Batch 140, MoE-Loss: 3.0656348826596513e-05
# Main contribution: 59.69%
# Dynamic Top-K: {'mean': 2.369748115539551, 'std': 0.4847775399684906, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6515792608261108
# Batch 160, C-Loss: 0.5060840845108032
# Batch 160, S-Loss: 1.4486217498779297
# Batch 160, MoE-Loss: 3.164301233482547e-05
# Main contribution: 58.98%
# Dynamic Top-K: {'mean': 2.6666667461395264, 'std': 0.4803844690322876, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6516587138175964
# Batch 180, C-Loss: 0.506129264831543
# Batch 180, S-Loss: 1.448814868927002
# Batch 180, MoE-Loss: 3.182499131071381e-05
# Main contribution: 59.47%
# Dynamic Top-K: {'mean': 2.646341323852539, 'std': 0.48104700446128845, 'min': 2.0, 'max': 3.0}
# At Epoch 10, Train Loss: 0.6463642120361328, Train C-Loss: 0.5064230561256409, Train S-Loss: 1.432637095451355, Train MoE-Loss: 3.195792669430375e-05, R2 score: 0.311905
# At Epoch 10, Val Loss: 0.6262919306755066, Val CLoss: 0.5051182508468628, Val SLoss: 1.373720645904541, Val MoELoss: 3.7247631553327665e-05, Val R2: 0.31187866666666664
# Val Main contribution: 60.37%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 3/20
# Epoch 11
# Batch 0, Loss: 0.7348638772964478
# Batch 0, C-Loss: 0.5030374526977539
# Batch 0, S-Loss: 1.7015153169631958
# Batch 0, MoE-Loss: 3.886103513650596e-05
# Main contribution: 60.39%
# Dynamic Top-K: {'mean': 2.5303030014038086, 'std': 0.5029052495956421, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6385028958320618
# Batch 20, C-Loss: 0.5063151121139526
# Batch 20, S-Loss: 1.409162998199463
# Batch 20, MoE-Loss: 3.053685213671997e-05
# Main contribution: 60.69%
# Dynamic Top-K: {'mean': 2.6307692527770996, 'std': 0.48635220527648926, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6429652571678162
# Batch 40, C-Loss: 0.5060029029846191
# Batch 40, S-Loss: 1.422853946685791
# Batch 40, MoE-Loss: 3.94581766158808e-05
# Main contribution: 60.02%
# Dynamic Top-K: {'mean': 3.0, 'std': 0.0, 'min': 3.0, 'max': 3.0}
# Batch 60, Loss: 0.6246531009674072
# Batch 60, C-Loss: 0.5087205171585083
# Batch 60, S-Loss: 1.3652013540267944
# Batch 60, MoE-Loss: 3.7626439734594896e-05
# Main contribution: 59.87%
# Dynamic Top-K: {'mean': 2.3119266033172607, 'std': 0.4654199182987213, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6418365836143494
# Batch 80, C-Loss: 0.5077708959579468
# Batch 80, S-Loss: 1.4177031517028809
# Batch 80, MoE-Loss: 3.578354153432883e-05
# Main contribution: 59.62%
# Dynamic Top-K: {'mean': 2.344827651977539, 'std': 0.47668376564979553, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.640667200088501
# Batch 100, C-Loss: 0.507204532623291
# Batch 100, S-Loss: 1.4147590398788452
# Batch 100, MoE-Loss: 3.8580892578465864e-05
# Main contribution: 60.29%
# Dynamic Top-K: {'mean': 2.527027130126953, 'std': 0.5026770234107971, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.629801869392395
# Batch 120, C-Loss: 0.5086674690246582
# Batch 120, S-Loss: 1.3806992769241333
# Batch 120, MoE-Loss: 3.9464764995500445e-05
# Main contribution: 60.18%
# Dynamic Top-K: {'mean': 2.4146339893341064, 'std': 0.4946737587451935, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6336308717727661
# Batch 140, C-Loss: 0.5083940625190735
# Batch 140, S-Loss: 1.3924587965011597
# Batch 140, MoE-Loss: 4.018044637632556e-05
# Main contribution: 60.18%
# Dynamic Top-K: {'mean': 2.6101694107055664, 'std': 0.4918980896472931, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6358550786972046
# Batch 160, C-Loss: 0.5078892111778259
# Batch 160, S-Loss: 1.3996349573135376
# Batch 160, MoE-Loss: 4.130610977881588e-05
# Main contribution: 59.25%
# Dynamic Top-K: {'mean': 2.5526316165924072, 'std': 0.5038966536521912, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6372154355049133
# Batch 180, C-Loss: 0.5076202750205994
# Batch 180, S-Loss: 1.4039853811264038
# Batch 180, MoE-Loss: 4.113679096917622e-05
# Main contribution: 59.36%
# Dynamic Top-K: {'mean': 2.4787232875823975, 'std': 0.5022256970405579, 'min': 2.0, 'max': 3.0}
# At Epoch 11, Train Loss: 0.6443658471107483, Train C-Loss: 0.5072469115257263, Train S-Loss: 1.42581045627594, Train MoE-Loss: 4.0672661270946264e-05, R2 score: 0.3066915
# At Epoch 11, Val Loss: 0.6378118395805359, Val CLoss: 0.5025009512901306, Val SLoss: 1.4109082221984863, Val MoELoss: 2.5867419026326388e-05, Val R2: 0.31144066666666664
# Val Main contribution: 60.26%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 4/20
# Epoch 12
# Batch 0, Loss: 0.5440356731414795
# Batch 0, C-Loss: 0.5064139366149902
# Batch 0, S-Loss: 1.12568199634552
# Batch 0, MoE-Loss: 1.096308187698014e-05
# Main contribution: 59.89%
# Dynamic Top-K: {'mean': 2.2903225421905518, 'std': 0.45513638854026794, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6364529132843018
# Batch 20, C-Loss: 0.5152431130409241
# Batch 20, S-Loss: 1.3940585851669312
# Batch 20, MoE-Loss: 5.7190118241123855e-05
# Main contribution: 60.17%
# Dynamic Top-K: {'mean': 2.447761058807373, 'std': 0.5010166168212891, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.621101438999176
# Batch 40, C-Loss: 0.5099292397499084
# Batch 40, S-Loss: 1.3533281087875366
# Batch 40, MoE-Loss: 4.689374691224657e-05
# Main contribution: 60.21%
# Dynamic Top-K: {'mean': 2.4533333778381348, 'std': 0.5011698007583618, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6267354488372803
# Batch 60, C-Loss: 0.5118433237075806
# Batch 60, S-Loss: 1.368320345878601
# Batch 60, MoE-Loss: 4.2209365346934646e-05
# Main contribution: 59.35%
# Dynamic Top-K: {'mean': 2.7291667461395264, 'std': 0.4490928649902344, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.631308913230896
# Batch 80, C-Loss: 0.5101287961006165
# Batch 80, S-Loss: 1.3837556838989258
# Batch 80, MoE-Loss: 4.179207098786719e-05
# Main contribution: 60.07%
# Dynamic Top-K: {'mean': 2.4383561611175537, 'std': 0.49961933493614197, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6260655522346497
# Batch 100, C-Loss: 0.5090937614440918
# Batch 100, S-Loss: 1.3690634965896606
# Batch 100, MoE-Loss: 3.931537503376603e-05
# Main contribution: 60.40%
# Dynamic Top-K: {'mean': 2.596774101257324, 'std': 0.49454987049102783, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6329813003540039
# Batch 120, C-Loss: 0.5087617635726929
# Batch 120, S-Loss: 1.3901457786560059
# Batch 120, MoE-Loss: 3.658895366243087e-05
# Main contribution: 60.01%
# Dynamic Top-K: {'mean': 2.3669354915618896, 'std': 0.4829433858394623, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6416652202606201
# Batch 140, C-Loss: 0.5087390542030334
# Batch 140, S-Loss: 1.4162205457687378
# Batch 140, MoE-Loss: 3.6393354093888775e-05
# Main contribution: 59.79%
# Dynamic Top-K: {'mean': 2.809523820877075, 'std': 0.40237390995025635, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6392528414726257
# Batch 160, C-Loss: 0.5087409615516663
# Batch 160, S-Loss: 1.4089821577072144
# Batch 160, MoE-Loss: 3.567288149497472e-05
# Main contribution: 60.06%
# Dynamic Top-K: {'mean': 2.9361701011657715, 'std': 0.24709226191043854, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6425732970237732
# Batch 180, C-Loss: 0.5081980228424072
# Batch 180, S-Loss: 1.419486403465271
# Batch 180, MoE-Loss: 3.535353243933059e-05
# Main contribution: 59.87%
# Dynamic Top-K: {'mean': 2.838709592819214, 'std': 0.37387827038764954, 'min': 2.0, 'max': 3.0}
# At Epoch 12, Train Loss: 0.6444053649902344, Train C-Loss: 0.5078691244125366, Train S-Loss: 1.42531156539917, Train MoE-Loss: 3.520691825542599e-05, R2 score: 0.30809
# At Epoch 12, Val Loss: 0.628808319568634, Val CLoss: 0.507837176322937, Val SLoss: 1.378554344177246, Val MoELoss: 3.2870892027858645e-05, Val R2: 0.311344
# Val Main contribution: 60.33%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 5/20
# Epoch 13
# Batch 0, Loss: 0.7720614671707153
# Batch 0, C-Loss: 0.5716238021850586
# Batch 0, S-Loss: 1.7445387840270996
# Batch 0, MoE-Loss: 2.17443703149911e-05
# Main contribution: 60.22%
# Dynamic Top-K: {'mean': 2.4787232875823975, 'std': 0.5022256970405579, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.650090217590332
# Batch 20, C-Loss: 0.517082929611206
# Batch 20, S-Loss: 1.4331539869308472
# Batch 20, MoE-Loss: 3.351100895088166e-05
# Main contribution: 60.48%
# Dynamic Top-K: {'mean': 2.7272727489471436, 'std': 0.45226702094078064, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6598665714263916
# Batch 40, C-Loss: 0.5123201012611389
# Batch 40, S-Loss: 1.467246413230896
# Batch 40, MoE-Loss: 3.343872231198475e-05
# Main contribution: 60.02%
# Dynamic Top-K: {'mean': 2.691176414489746, 'std': 0.4654432535171509, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6500018835067749
# Batch 60, C-Loss: 0.5100436806678772
# Batch 60, S-Loss: 1.4399299621582031
# Batch 60, MoE-Loss: 3.2024330721469596e-05
# Main contribution: 59.74%
# Dynamic Top-K: {'mean': 2.8399999141693115, 'std': 0.37416574358940125, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6407710313796997
# Batch 80, C-Loss: 0.510192334651947
# Batch 80, S-Loss: 1.4120875597000122
# Batch 80, MoE-Loss: 3.339783143019304e-05
# Main contribution: 60.58%
# Dynamic Top-K: {'mean': 2.3523809909820557, 'std': 0.48000308871269226, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6396498680114746
# Batch 100, C-Loss: 0.5098068714141846
# Batch 100, S-Loss: 1.409109115600586
# Batch 100, MoE-Loss: 3.382470094948076e-05
# Main contribution: 59.85%
# Dynamic Top-K: {'mean': 2.442105293273926, 'std': 0.4992716312408447, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6353631615638733
# Batch 120, C-Loss: 0.5091155767440796
# Batch 120, S-Loss: 1.3969416618347168
# Batch 120, MoE-Loss: 3.224908505217172e-05
# Main contribution: 59.74%
# Dynamic Top-K: {'mean': 2.5108695030212402, 'std': 0.5026209354400635, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6412795186042786
# Batch 140, C-Loss: 0.5084758400917053
# Batch 140, S-Loss: 1.4153305292129517
# Batch 140, MoE-Loss: 3.2337105949409306e-05
# Main contribution: 60.92%
# Dynamic Top-K: {'mean': 2.3418805599212646, 'std': 0.4763799011707306, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6379531621932983
# Batch 160, C-Loss: 0.5093775391578674
# Batch 160, S-Loss: 1.4044486284255981
# Batch 160, MoE-Loss: 3.330870094941929e-05
# Main contribution: 60.37%
# Dynamic Top-K: {'mean': 2.6173911094665527, 'std': 0.4881509840488434, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6395505666732788
# Batch 180, C-Loss: 0.5095053911209106
# Batch 180, S-Loss: 1.4091120958328247
# Batch 180, MoE-Loss: 3.382986687938683e-05
# Main contribution: 60.05%
# Dynamic Top-K: {'mean': 2.5957446098327637, 'std': 0.49605289101600647, 'min': 2.0, 'max': 3.0}
# At Epoch 13, Train Loss: 0.6441787481307983, Train C-Loss: 0.5092421770095825, Train S-Loss: 1.42325758934021, Train MoE-Loss: 3.638593989307992e-05, R2 score: 0.310179
# At Epoch 13, Val Loss: 0.6344034671783447, Val CLoss: 0.5031183362007141, Val SLoss: 1.400080680847168, Val MoELoss: 1.12744455691427e-05, Val R2: 0.31118666666666667
# Val Main contribution: 59.92%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 6/20
# Epoch 14
# Batch 0, Loss: 0.6464163064956665
# Batch 0, C-Loss: 0.5045013427734375
# Batch 0, S-Loss: 1.4347364902496338
# Batch 0, MoE-Loss: 1.1109113074780907e-05
# Main contribution: 59.89%
# Dynamic Top-K: {'mean': 2.436781644821167, 'std': 0.49886268377304077, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6522092819213867
# Batch 20, C-Loss: 0.5046716928482056
# Batch 20, S-Loss: 1.4519193172454834
# Batch 20, MoE-Loss: 3.691832171170972e-05
# Main contribution: 60.82%
# Dynamic Top-K: {'mean': 2.50649356842041, 'std': 0.5032362937927246, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6622939109802246
# Batch 40, C-Loss: 0.5057317018508911
# Batch 40, S-Loss: 1.4810882806777954
# Batch 40, MoE-Loss: 6.167178798932582e-05
# Main contribution: 60.84%
# Dynamic Top-K: {'mean': 2.875, 'std': 0.34156501293182373, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6521604657173157
# Batch 60, C-Loss: 0.5054008364677429
# Batch 60, S-Loss: 1.4510307312011719
# Batch 60, MoE-Loss: 5.0055707106366754e-05
# Main contribution: 59.75%
# Dynamic Top-K: {'mean': 2.5164835453033447, 'std': 0.5024968385696411, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6464552283287048
# Batch 80, C-Loss: 0.5075618028640747
# Batch 80, S-Loss: 1.4317615032196045
# Batch 80, MoE-Loss: 4.249700214131735e-05
# Main contribution: 60.34%
# Dynamic Top-K: {'mean': 2.7291667461395264, 'std': 0.4490928649902344, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.64897221326828
# Batch 100, C-Loss: 0.5070499777793884
# Batch 100, S-Loss: 1.4398279190063477
# Batch 100, MoE-Loss: 3.882296005031094e-05
# Main contribution: 60.35%
# Dynamic Top-K: {'mean': 2.5208334922790527, 'std': 0.5048523545265198, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6496036648750305
# Batch 120, C-Loss: 0.5066863894462585
# Batch 120, S-Loss: 1.4420883655548096
# Batch 120, MoE-Loss: 3.631668005255051e-05
# Main contribution: 60.45%
# Dynamic Top-K: {'mean': 2.5609755516052246, 'std': 0.4993220567703247, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6399674415588379
# Batch 140, C-Loss: 0.5066505670547485
# Batch 140, S-Loss: 1.413216471672058
# Batch 140, MoE-Loss: 3.542088597896509e-05
# Main contribution: 59.80%
# Dynamic Top-K: {'mean': 2.2727272510528564, 'std': 0.44705840945243835, 'min': 2.0, 'max': 3.0}
# ...
# Main contribution: 57.92%
# Dynamic Top-K: {'mean': 2.4905660152435303, 'std': 0.504694938659668, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6461953520774841
# Batch 140, C-Loss: 0.5057722330093384
# Batch 140, S-Loss: 1.432479977607727
# Batch 140, MoE-Loss: 0.00033399774110876024
# Main contribution: 58.50%
# Dynamic Top-K: {'mean': 2.611764669418335, 'std': 0.4902409315109253, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6487266421318054
# Batch 160, C-Loss: 0.5054582953453064
# Batch 160, S-Loss: 1.4404191970825195
# Batch 160, MoE-Loss: 0.00030234880978241563
# Main contribution: 59.30%
# Dynamic Top-K: {'mean': 2.7948718070983887, 'std': 0.4090738594532013, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6398946046829224
# Batch 180, C-Loss: 0.5054977536201477
# Batch 180, S-Loss: 1.4139132499694824
# Batch 180, MoE-Loss: 0.00027273138402961195
# Main contribution: 60.71%
# Dynamic Top-K: {'mean': 2.4324324131011963, 'std': 0.4987952709197998, 'min': 2.0, 'max': 3.0}
# At Epoch 40, Train Loss: 0.6374707818031311, Train C-Loss: 0.5055152773857117, Train S-Loss: 1.406645655632019, Train MoE-Loss: 0.0002511239727027714, R2 score: 0.3100055
# At Epoch 40, Val Loss: 0.6221563220024109, Val CLoss: 0.5039026737213135, Val SLoss: 1.3624869585037231, Val MoELoss: 7.902415381977335e-05, Val R2: 0.3145393333333333
# Val Main contribution: 60.79%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 17/20
# Epoch 41
# Batch 0, Loss: 0.5677908658981323
# Batch 0, C-Loss: 0.5067977905273438
# Batch 0, S-Loss: 1.1965657472610474
# Batch 0, MoE-Loss: 9.10222479433287e-06
# Main contribution: 59.91%
# Dynamic Top-K: {'mean': 2.433734893798828, 'std': 0.4986022710800171, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6258668899536133
# Batch 20, C-Loss: 0.5039632320404053
# Batch 20, S-Loss: 1.3736042976379395
# Batch 20, MoE-Loss: 3.3197513403138146e-05
# Main contribution: 60.14%
# Dynamic Top-K: {'mean': 2.369748115539551, 'std': 0.4847775399684906, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6372235417366028
# Batch 40, C-Loss: 0.5045985579490662
# Batch 40, S-Loss: 1.4070347547531128
# Batch 40, MoE-Loss: 3.718883453984745e-05
# Main contribution: 60.86%
# Dynamic Top-K: {'mean': 2.3523809909820557, 'std': 0.48000308871269226, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6490334272384644
# Batch 60, C-Loss: 0.5050060153007507
# Batch 60, S-Loss: 1.4420579671859741
# Batch 60, MoE-Loss: 3.631028448580764e-05
# Main contribution: 60.20%
# Dynamic Top-K: {'mean': 2.5164835453033447, 'std': 0.5024968385696411, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6305737495422363
# Batch 80, C-Loss: 0.505480170249939
# Batch 80, S-Loss: 1.3862051963806152
# Batch 80, MoE-Loss: 3.589785410440527e-05
# Main contribution: 60.67%
# Dynamic Top-K: {'mean': 2.2903225421905518, 'std': 0.45513638854026794, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6274557113647461
# Batch 100, C-Loss: 0.5051962733268738
# Batch 100, S-Loss: 1.3771302700042725
# Batch 100, MoE-Loss: 4.043964872835204e-05
# Main contribution: 60.50%
# Dynamic Top-K: {'mean': 3.0, 'std': 0.0, 'min': 3.0, 'max': 3.0}
# Batch 120, Loss: 0.6251429915428162
# Batch 120, C-Loss: 0.5049824118614197
# Batch 120, S-Loss: 1.3704010248184204
# Batch 120, MoE-Loss: 4.5561529987026006e-05
# Main contribution: 60.67%
# Dynamic Top-K: {'mean': 2.6458334922790527, 'std': 0.48332110047340393, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6325299739837646
# Batch 140, C-Loss: 0.5050156712532043
# Batch 140, S-Loss: 1.3925293684005737
# Batch 140, MoE-Loss: 4.4984852138441056e-05
# Main contribution: 59.82%
# Dynamic Top-K: {'mean': 2.555555820465088, 'std': 0.5008952617645264, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6329982876777649
# Batch 160, C-Loss: 0.505128800868988
# Batch 160, S-Loss: 1.393821358680725
# Batch 160, MoE-Loss: 4.527847340796143e-05
# Main contribution: 60.85%
# Dynamic Top-K: {'mean': 2.3684210777282715, 'std': 0.4849355220794678, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6327534317970276
# Batch 180, C-Loss: 0.5048807263374329
# Batch 180, S-Loss: 1.3933353424072266
# Batch 180, MoE-Loss: 4.4819586037192494e-05
# Main contribution: 60.27%
# Dynamic Top-K: {'mean': 2.348484992980957, 'std': 0.4801417887210846, 'min': 2.0, 'max': 3.0}
# At Epoch 41, Train Loss: 0.6329666376113892, Train C-Loss: 0.5047983527183533, Train S-Loss: 1.3940566778182983, Train MoE-Loss: 4.534019171842374e-05, R2 score: 0.31575500000000006
# At Epoch 41, Val Loss: 0.6228154897689819, Val CLoss: 0.5035006999969482, Val SLoss: 1.3648587465286255, Val MoELoss: 8.707379311090335e-05, Val R2: 0.31410533333333335
# Val Main contribution: 60.87%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 18/20
# Epoch 42
# Batch 0, Loss: 0.7315644025802612
# Batch 0, C-Loss: 0.5011138916015625
# Batch 0, S-Loss: 1.6934417486190796
# Batch 0, MoE-Loss: 0.000137275448651053
# Main contribution: 58.63%
# Dynamic Top-K: {'mean': 2.8620688915252686, 'std': 0.35093119740486145, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.6597182750701904
# Batch 20, C-Loss: 0.5046712756156921
# Batch 20, S-Loss: 1.4744443893432617
# Batch 20, MoE-Loss: 3.894936162396334e-05
# Main contribution: 60.21%
# Dynamic Top-K: {'mean': 2.326923131942749, 'std': 0.47136056423187256, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6412648558616638
# Batch 40, C-Loss: 0.5054764151573181
# Batch 40, S-Loss: 1.4182802438735962
# Batch 40, MoE-Loss: 3.782116255024448e-05
# Main contribution: 59.51%
# Dynamic Top-K: {'mean': 2.279411792755127, 'std': 0.4503690004348755, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6358559727668762
# Batch 60, C-Loss: 0.5053588151931763
# Batch 60, S-Loss: 1.402130365371704
# Batch 60, MoE-Loss: 7.846611697459593e-05
# Main contribution: 58.21%
# Dynamic Top-K: {'mean': 2.4369750022888184, 'std': 0.49810925126075745, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.6317591071128845
# Batch 80, C-Loss: 0.505666971206665
# Batch 80, S-Loss: 1.389462947845459
# Batch 80, MoE-Loss: 0.00014706204819958657
# Main contribution: 54.22%
# Dynamic Top-K: {'mean': 2.4867255687713623, 'std': 0.5020501613616943, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6253163814544678
# Batch 100, C-Loss: 0.5063205361366272
# Batch 100, S-Loss: 1.3693791627883911
# Batch 100, MoE-Loss: 0.0002494807995390147
# Main contribution: 52.84%
# Dynamic Top-K: {'mean': 2.3418805599212646, 'std': 0.4763799011707306, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6326821446418762
# Batch 120, C-Loss: 0.5069130063056946
# Batch 120, S-Loss: 1.3908032178878784
# Batch 120, MoE-Loss: 0.0003302004188299179
# Main contribution: 51.72%
# Dynamic Top-K: {'mean': 2.3851852416992188, 'std': 0.4884514808654785, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6308823823928833
# Batch 140, C-Loss: 0.5065754055976868
# Batch 140, S-Loss: 1.3856686353683472
# Batch 140, MoE-Loss: 0.000403449812438339
# Main contribution: 52.72%
# Dynamic Top-K: {'mean': 2.361445665359497, 'std': 0.4833398759365082, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.630609393119812
# Batch 160, C-Loss: 0.5064354538917542
# Batch 160, S-Loss: 1.3849644660949707
# Batch 160, MoE-Loss: 0.0004283876623958349
# Main contribution: 55.18%
# Dynamic Top-K: {'mean': 2.6000001430511475, 'std': 0.49613896012306213, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6361455917358398
# Batch 180, C-Loss: 0.5072770118713379
# Batch 180, S-Loss: 1.4007269144058228
# Batch 180, MoE-Loss: 0.00043307337909936905
# Main contribution: 55.16%
# Dynamic Top-K: {'mean': 2.4285714626312256, 'std': 0.4988465905189514, 'min': 2.0, 'max': 3.0}
# At Epoch 42, Train Loss: 0.6388766169548035, Train C-Loss: 0.5069929361343384, Train S-Loss: 1.409208059310913, Train MoE-Loss: 0.0004288643831387162, R2 score: 0.3122545
# At Epoch 42, Val Loss: 0.6271368265151978, Val CLoss: 0.503675103187561, Val SLoss: 1.3774092197418213, Val MoELoss: 0.000325822620652616, Val R2: 0.3136946666666666
# Val Main contribution: 56.74%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 19/20
# Epoch 43
# Batch 0, Loss: 0.6059014797210693
# Batch 0, C-Loss: 0.5012989044189453
# Batch 0, S-Loss: 1.316128134727478
# Batch 0, MoE-Loss: 0.000277230137726292
# Main contribution: 57.23%
# Dynamic Top-K: {'mean': 2.5438597202301025, 'std': 0.5024999976158142, 'min': 2.0, 'max': 3.0}
# Batch 20, Loss: 0.5819118022918701
# Batch 20, C-Loss: 0.5036603212356567
# Batch 20, S-Loss: 1.241812825202942
# Batch 20, MoE-Loss: 0.00026195941609330475
# Main contribution: 58.20%
# Dynamic Top-K: {'mean': 2.460869550704956, 'std': 0.5006479620933533, 'min': 2.0, 'max': 3.0}
# Batch 40, Loss: 0.6210640668869019
# Batch 40, C-Loss: 0.5040445923805237
# Batch 40, S-Loss: 1.3589457273483276
# Batch 40, MoE-Loss: 0.0002017343940678984
# Main contribution: 59.31%
# Dynamic Top-K: {'mean': 2.3684210777282715, 'std': 0.48885151743888855, 'min': 2.0, 'max': 3.0}
# Batch 60, Loss: 0.6328306198120117
# Batch 60, C-Loss: 0.5041415095329285
# Batch 60, S-Loss: 1.3941998481750488
# Batch 60, MoE-Loss: 0.0001501095830462873
# Main contribution: 59.56%
# Dynamic Top-K: {'mean': 2.4324324131011963, 'std': 0.4987952709197998, 'min': 2.0, 'max': 3.0}
# Batch 80, Loss: 0.630402147769928
# Batch 80, C-Loss: 0.503871500492096
# Batch 80, S-Loss: 1.3872181177139282
# Batch 80, MoE-Loss: 0.00011653162073343992
# Main contribution: 59.98%
# Dynamic Top-K: {'mean': 2.7317070960998535, 'std': 0.4485749900341034, 'min': 2.0, 'max': 3.0}
# Batch 100, Loss: 0.6267890334129333
# Batch 100, C-Loss: 0.5039322376251221
# Batch 100, S-Loss: 1.3763349056243896
# Batch 100, MoE-Loss: 9.988039528252557e-05
# Main contribution: 59.23%
# Dynamic Top-K: {'mean': 2.625, 'std': 0.49186936020851135, 'min': 2.0, 'max': 3.0}
# Batch 120, Loss: 0.6268482804298401
# Batch 120, C-Loss: 0.5045230984687805
# Batch 120, S-Loss: 1.3759361505508423
# Batch 120, MoE-Loss: 8.607165364082903e-05
# Main contribution: 59.83%
# Dynamic Top-K: {'mean': 2.436781644821167, 'std': 0.49886268377304077, 'min': 2.0, 'max': 3.0}
# Batch 140, Loss: 0.6306961178779602
# Batch 140, C-Loss: 0.5047982931137085
# Batch 140, S-Loss: 1.3872150182724
# Batch 140, MoE-Loss: 7.512752199545503e-05
# Main contribution: 59.82%
# Dynamic Top-K: {'mean': 2.9487180709838867, 'std': 0.22345586121082306, 'min': 2.0, 'max': 3.0}
# Batch 160, Loss: 0.6313913464546204
# Batch 160, C-Loss: 0.5050998330116272
# Batch 160, S-Loss: 1.3890045881271362
# Batch 160, MoE-Loss: 6.986635708017275e-05
# Main contribution: 60.37%
# Dynamic Top-K: {'mean': 2.8285715579986572, 'std': 0.38238525390625, 'min': 2.0, 'max': 3.0}
# Batch 180, Loss: 0.6304786205291748
# Batch 180, C-Loss: 0.5050370097160339
# Batch 180, S-Loss: 1.3863338232040405
# Batch 180, MoE-Loss: 6.548069359268993e-05
# Main contribution: 60.25%
# Dynamic Top-K: {'mean': 2.5441176891326904, 'std': 0.5017528533935547, 'min': 2.0, 'max': 3.0}
# At Epoch 43, Train Loss: 0.6297808885574341, Train C-Loss: 0.5051680207252502, Train S-Loss: 1.3841140270233154, Train MoE-Loss: 6.147395470179617e-05, R2 score: 0.31395850000000003
# At Epoch 43, Val Loss: 0.6238395571708679, Val CLoss: 0.5030246376991272, Val SLoss: 1.3684709072113037, Val MoELoss: 2.275732549605891e-05, Val R2: 0.3144986666666667
# Val Main contribution: 60.23%
# Val Dynamic Top-K: {'mean': 2.5305773337682087, 'std': 0.46984738945960997, 'min': 2.013333333333333, 'max': 3.0}
# Early stopping counter: 20/20
#
# Early stopping triggered! Val ROUGE-2 hasn't improved for 20 epochs.
# Best Val ROUGE-2: 0.3159
# wandb: uploading output.log; uploading config.yaml; uploading working/c_1_0.3118606666666667.mdl; uploading working/c_3_0.312058.mdl; uploading working/c_7_0.3130266666666667.mdl (+ 4 more)
# wandb: uploading working/c_1_0.3118606666666667.mdl; uploading working/c_3_0.312058.mdl; uploading working/c_7_0.3130266666666667.mdl; uploading working/c_15_0.313472.mdl; uploading working/c_19_0.31512199999999996.mdl (+ 2 more)
# wandb: uploading working/c_1_0.3118606666666667.mdl; uploading working/c_3_0.312058.mdl; uploading working/c_7_0.3130266666666667.mdl; uploading working/c_15_0.313472.mdl; uploading working/c_23_0.3158586666666667.mdl (+ 1 more)
# wandb: uploading history steps 534-534, summary, console lines 2901-2907
# wandb:
# wandb:
# wandb: Run history:
# wandb:                    best_epoch ▁▁▂▃▆▇█
# wandb:                   best_rouge2 ▁▆▆▇▇██
# wandb:                         epoch ▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇███
# wandb:                   train/batch ▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇███
# wandb:            train/batch_c_loss █▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁
# wandb:              train/batch_loss █▃▄▄▃▄▄▂▃▃▄▃▄▃▄▃▃▃▃▄▃▃▃▃▂▃▁▃▃▃▄▃▃▄▃▃▃▃▃▂
# wandb:          train/batch_moe_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▂▃▃▃▃▃▁▁▁▁▂
# wandb:            train/batch_rouge2 ▂▂▃▄▄▄▃▄▃▄█▄▄▄▃▃▄▃▄▄▄▇▄▅▄▄▄▄▄▄▁▃▄▄▄▃▄▄▄▄
# wandb:            train/batch_s_loss ▃▂▇▂▂▂▁▂▄▂▂▁▁▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▁▂▂█▂▂▁▃▂▂▂
# wandb:            train/epoch_c_loss █▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              train/epoch_loss █▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▂▂▁▂▂▂▁▁▁▁▁▁▁▂▂▂▁▁▁▁▁
# wandb:          train/epoch_moe_loss ▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃█▃▆▄▂▁▁
# wandb:            train/epoch_rouge2 ▁▅▆▇▇▇▇▇▆▇▇▇▇▇▇▇▇▇▇▇▆█▇▇▇▇▆▇▇██▇▇▇▆▇█▇██
# wandb:            train/epoch_s_loss █▆▄▄▄▃▃▄▃▄▃▃▃▃▃▃▂▃▃▃▃▂▃▃▃▂▂▂▂▂▂▂▃▅▃▂▂▂▁▁
# wandb: train/main_contribution_ratio ▃▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▆█▁
# wandb:                train/topk_max ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               train/topk_mean ▆▁▃▃▄▁▆▂█▇▃▄▄▃▃▄█▁▆▃▂▁▂▂▂▄▃▄▅▃▄▄▃▁▂▂▂▅▂█
# wandb:                train/topk_min ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                train/topk_std ███▇▆█▇███▄▇▇▇█████▄▇██▇▇█████▇█▇██▁▇███
# wandb:                    val/c_loss ▁▃▆▆▂▃▅▂▁▁▁▅▂▂▂▂▄▁▂▁▂▃▂▂▂▂▃▅▂▂▂▂█▃▂▂▁▂▂▂
# wandb:                      val/loss █▆▄▂▃▂▂▃▂▇▄▂▃▄▂▃█▂▂▁▃▄▃▁▂▃▃▁▂▂▃▁▅▄▃▂▂▁▁▁
# wandb:   val/main_contribution_ratio ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▂▃▃▃▁▁▁
# wandb:                  val/moe_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▂▃▃▂▁▁▁
# wandb:                    val/rouge2 ▁▆▆▆▅▆▆▇▆▇▆▆▆▆▇▇▇▆█▇▇█▇▇▇▇▇▇▇▇█▇▇▁███▇▇▇
# wandb:                    val/s_loss █▆▄▂▃▂▂▃▂▇▄▂▃▄▂▃█▂▂▂▃▄▃▁▂▃▃▁▂▂▃▁▄▄▃▂▂▁▁▁
# wandb:                  val/topk_max ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 val/topk_mean ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  val/topk_min ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  val/topk_std ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                    best_epoch 23
# wandb:                   best_rouge2 0.31586
# wandb:                         epoch 43
# wandb:                   train/batch 8780
# wandb:            train/batch_c_loss 0.50504
# wandb:              train/batch_loss 0.63048
# wandb:          train/batch_moe_loss 7e-05
# wandb:            train/batch_rouge2 0.31692
# wandb:            train/batch_s_loss 1.38633
# wandb:            train/epoch_c_loss 0.50517
# wandb:              train/epoch_loss 0.62978
# wandb:          train/epoch_moe_loss 6e-05
# wandb:            train/epoch_rouge2 0.31396
# wandb:            train/epoch_s_loss 1.38411
# wandb: train/main_contribution_ratio 0.60246
# wandb:                train/topk_max 3
# wandb:               train/topk_mean 2.54412
# wandb:                train/topk_min 2
# wandb:                train/topk_std 0.50175
# wandb:                    val/c_loss 0.50302
# wandb:                      val/loss 0.62384
# wandb:   val/main_contribution_ratio 0.60228
# wandb:                  val/moe_loss 2e-05
# wandb:                    val/rouge2 0.3145
# wandb:                    val/s_loss 1.36847
# wandb:                  val/topk_max 3
# wandb:                 val/topk_mean 2.53058
# wandb:                  val/topk_min 2.01333
# wandb:                  val/topk_std 0.46985
# wandb:
# wandb: 🚀 View run Abmusu_weight_blend_concateV2_contribute_DynTopK-True_TMC-0.6 at: https://wandb.ai/TripleAIML/MoEGAT/runs/1agf5aeo
# wandb: ⭐️ View project at: https://wandb.ai/TripleAIML/MoEGAT
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 7 other file(s)
# wandb: Find logs at: ./wandb/run-20251122_172003-1agf5aeo/logs

# %% [markdown]
# # Evaluation

# %%
c_file_path = model_save_path
e_file_path = c_file_path.replace("/c_", "/e_")

# %%
c_file_path
# Out:
# '/kaggle/working/c_23_0.3158586666666667.mdl'

# %%
c_graph_encoder = StepWiseGraphConvLayerMoE(in_dim=args['input'], out_dim=args['hidden'], hid_dim=args['hidden'],
                                         dropout_p=args['dropout'], act=nn.LeakyReLU(), nheads=args['heads'], iter=1, 
                                            num_experts=moe_args['num_experts'], top_k=moe_args['top_k'], use_dynamic_topk=moe_args['use_dynamic_topk']).to(device)


contrast_filter = Contrast_Encoder(c_graph_encoder, args['hidden'], dropout_p=args['dropout']).to(device)
summarization_encoder = End2End_Encoder(args['input'], args['hidden'], args['dropout']).to(device)

# %%
summarization_encoder.load_state_dict(torch.load(e_file_path, map_location=torch.device('cuda')), strict=False)
contrast_filter.load_state_dict(torch.load(c_file_path, map_location=torch.device('cuda')), strict=False)
model = [contrast_filter, summarization_encoder]

# %%
predicts, goldens = test_e2e(testGraphs, model, args["max_word_num"], args["kappa"])
rouge_scores = get_rouges(goldens, predicts)
bert_score = get_bert_score(goldens, predicts)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# 2025-11-22 17:51:11.650839: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763833871.827130      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763833871.876588      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/5 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/3 [00:00<?, ?it/s]
# done in 12.39 seconds, 12.10 sentences/sec

# %%
def print_evaluation_scores(rouge_means, bert):
    for rouge_type, metrics in rouge_means.items():
        print(f"{rouge_type.upper()} Scores:")
        for metric, value in metrics.items():
            print(f"  {metric}: {value:.4f}")
        print()
        
    print("Bert Scores:")
    for metric, value in bert.items():
        print(f"  {metric}: {value:.4f}")

# %%
print_evaluation_scores(rouge_scores, bert_score)
# Out:
# ROUGE1 Scores:
#   p: 0.4668
#   r: 0.5999
#   f: 0.5151
#
# ROUGE2 Scores:
#   p: 0.2801
#   r: 0.3888
#   f: 0.3159
#
# ROUGEL Scores:
#   p: 0.4376
#   r: 0.5618
#   f: 0.4826
#
# Bert Scores:
#   precision: 0.9052
#   recall: 0.9086
#   fmeasure: 0.9069

# %%
def print_for_copy(rouge_means, bert):
    for rouge_type, metrics in rouge_means.items():
        for metric, value in metrics.items():
            print(f"{value:.4f}", end="\t")
        
    for metric, value in bert.items():
        print(f" {value:.4f}", end="\t")

# %%
print_for_copy(rouge_scores, bert_score)
# Out:
# 0.4668	0.5999	0.5151	0.2801	0.3888	0.3159	0.4376	0.5618	0.4826	 0.9052	 0.9086	 0.9069

# %%
# Lưu predicts ra file
with open("predicts.txt", "w", encoding="utf-8") as f:
    for line in predicts:
        f.write(line.strip() + "\n")

# Lưu goldens ra file
with open("goldens.txt", "w", encoding="utf-8") as f:
    for line in goldens:
        f.write(line.strip() + "\n")
